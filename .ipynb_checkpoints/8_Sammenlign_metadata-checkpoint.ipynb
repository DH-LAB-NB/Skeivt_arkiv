# %% [markdown]
# ![DHlab_logo_web_no_red.png](attachment:DHlab_logo_web_no_red.png)

# %%
from dhlab.module_update import css
import dhlab.nbtext as nb
import dhlab.token_map as tm
import dhlab.graph_networkx_louvain as gnl
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# # 1. Undersøk korpus med metadata
#
#
# En viktig metode i undersøkelse av metadata og tekster er grafer og nettverk.

# %% [markdown]
# ## 1.1. Bygg korpus

# %% [markdown]
# Korpuset defineres med metadata som dewey, emneord, navn , år, etc. Her kan [Webdewey](http://deweysearchno.pansoft.de/webdeweysearch/index.html) være til god hjelp.
#
# Se eksempelfil om [Korpusbygging](https://nbviewer.jupyter.org/github/DH-LAB-NB/DHLAB/blob/master/1_Bygg_korpus.ipynb) for ulike måter å definere korpus.

# %%
# ddk 335 er sosialisme

bøker = nb.book_corpus(
    period=(1950, 2020),
    #title='%',
    #subject='',
    ddk='306.76%', limit=300)

# %%
bøker
# Out:
#               urn                          author  \
# 0   2014013106088                 Nordbø, Arnfinn
# 1   2016093008047                Arterburn, Jerry
# 2   2015090706160            Kristiansen, Hans W.
# 3   2014051508085
# 4   2013062106129        Chepstow-Lusty, Lill-Ann
# 5   2010090208061                       Jon, Nina
# 6   2014022006154
# 7   2014110708160                 Arntzen, Marion
# 8   2015102608073  Benestad, Esben Esther Pirelli
# 9   2013013108075                 Hellesund, Tone
# 10  2015021106132                 Wegling, Monica
# 11  2013101508115
# 12  2015062208082                   Lützen, Karin
# 13  2008111404025           Middelthon, Anne-Lise
# 14  2007062704007             Olsen, Bjørn Gunnar
# 15  2007110104044             Ringdal, Nils Johan
# 16  2013071705069                 Hegna, Kristinn
# 17  2014040905073
# 18  2008060400072                  Prieur, Annick
# 19  2011022308134
# 20  2013071608133                      Aden, Amal
# 21  2013061306023           Sekkingstad, Maren K.
# 22  2010042808010         Friele, Karen-Christine
# 23  2008112500081
# 24  2008061001001         Friele, Karen-Christine
# 25  2008112704088                    Nissen, Axel
# 26  2009030404112                 Wegling, Monica
# 27  2013071608156                  Jordåen, Runar
# 28  2014022406029       Haugen-Flermoe, Christian
# 29  2008060200059         Friele, Karen-Christine
# 30  2007112101082
# 31  2008011004011                 Gåsland, Anders
# 32  2013070508067                  Lindstad, Siri
# 33  2007110200036            Andersen, Arnfinn J.
# 34  2014022808279
# 35  2007080200076
# 36  2014030506032               Anderssen, Norman
# 37  2011041108143
# 38  2016070608135                    Bolsø, Agnes
# 39  2010091508128
# 40  2012121106071             Seehuus, Jonas Rein
# 41  2009031904022                    Voll, Jorunn
# 42  2014021748081
# 43  2013080838129                  Bjørkman, Mari
# 44  2012062205006            Moseng, Bera Ulstein
# 45  2008090400026                 Hegna, Kristinn
# 46  2011061408121
# 47  2011102706039                 Thoresen, Bente
# 48  2008112601015  Benestad, Esben Esther Pirelli
# 49  2007112601052                   Wikstøl, Rune
# 50  2013120506015                  Fischer, Erica
#
#                                                 title  year
# 0                              Betre død enn homofil?  2009
# 1                                    Hva vil mor si -  1989
# 2                                  Masker og motstand  2008
# 3                              Med regnbuen som våpen  1995
# 4                                            Gay kids  2008
# 5   Biseksuelle menn - seksuell praksis og hiv-for...  1998
# 6   Lesbiske og homofile i møte med helse- og sosi...  2006
# 7                                   Mann er da kvinne  2011
# 8                            Transekjønn og diagnoser  2004
# 9                             Identitet på liv og død  2008
# 10                              -og ikke nok med det!  2001
# 11            Når heteroseksualiteten må forklare seg  2007
# 12                               Hva hjertet begjærer  1987
# 13          Being young and gay in the context of HIV  2001
# 14                                         To kvinner  1983
# 15                                       Lystens død?  1991
# 16                                              Homo?  2007
# 17                         Regjeringens handlingsplan  2009
# 18               Kjærlighet mellom menn i aidsens tid  1988
# 19                      Elsk meg litt, elsk meg lenge  2000
# 20                      Om håpet glipper, er alt tapt  2012
# 21                            Skeiv, normal, lykkelig  2007
# 22                           Fangene med rosa trekant  1995
# 23                                Norsk homoforskning  2001
# 24                                  Troll skal temmes  1990
# 25                                        Homo/hetero  2001
# 26                                        Trine Marit  1997
# 27                            Inversjon og perversjon  2010
# 28                                          Homo-quiz  2011
# 29                                  De forsvant bare-  1985
# 30                           Homofili er ikke medfødt  1993
# 31                                     Alltid freidig  1993
# 32                         Å fylle L-ordet med mening  2010
# 33                Homofile og lesbiskes livssituasjon  1988
# 34                                    Skeiv i sørvest  2008
# 35                       Nye perspektiver på homofili  1985
# 36  Holdninger til lesbiske kvinner, homofile menn...  2008
# 37                                             Barfot  2002
# 38                                Power in the erotic  2002
# 39                                           Homofili  1990
# 40                              Rødt, hvitt og skrått  2009
# 41                                Du skal ikkje elske  1993
# 42                                      Skapsprengere  2009
# 43                 Lesbisk selvtillit - lesbisk helse  2012
# 44        Lesbiske og homofile med innvandrerbakgrunn  2003
# 45  Levekår og livskvalitet blant lesbiske kvinner...  1999
# 46                                         Annen dans  2008
# 47                          Homofili og psykisk helse  2002
# 48                                  Kjønn i bevegelse  2001
# 49                                Det skeive mangfald  1993
# 50                                    Aimée og Jaguar  1994

# %% [markdown]
# ## 1.2. Undersøk forskjeller

# %% [markdown]
# ### 1.2.1. Undersøk forskjeller internt i korpuset

# %% [markdown]
# Her samler vi sammen alle bøkene i korpus og summerer. Men først la oss se på en del av korpuset som en dokument term matrise

# %%
# tar de fem første og henter frekvensene for alle bøkene

bøker_dtm = nb.get_corpus_text(nb.pure_urn(bøker)[:5])

# %%
bøker_dtm
# Out:
#                            2007110104044  2013071705069  2010091508128  \
# ?                                14817.0          321.0           55.0
# ,                                 2721.0         5697.0         3266.0
# .                                 2618.0         5434.0         2926.0
# og                                1852.0         1735.0         1572.0
# i                                 1510.0         1288.0         1141.0
# ...                                  ...            ...            ...
# .4                                   NaN            NaN            NaN
# .35                                  NaN            NaN            NaN
# .33                                  NaN            NaN            NaN
# .3                                   NaN            NaN            NaN
# (object-signinterpretant)            NaN            NaN            NaN
#
#                            2015062208082  2008111404025
# ?                                  191.0           12.0
# ,                                 7008.0         3659.0
# .                                 5967.0         3494.0
# og                                3492.0           30.0
# i                                 2929.0           18.0
# ...                                  ...            ...
# .4                                   NaN            1.0
# .35                                  NaN            1.0
# .33                                  NaN            1.0
# .3                                   NaN            1.0
# (object-signinterpretant)            NaN            1.0
#
# [41255 rows x 5 columns]

# %% [markdown]
# #### 1.2.1.1. Visualiser med varmekart

# %% [markdown]
# Et varmekart gjør det enklere å få øye på likhet og variasjon i tallene.

# %%
nb.heatmap(bøker_dtm.head(50), color='#045599')
# Out:
# <style  type="text/css" >
#     #T_78e0669c_f4b9_11e9_aa15_acde48001122row0_col0 {
#             background-color:  #045599;
#             color:  #f1f1f1;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row0_col1 {
#             background-color:  #daebf9;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row0_col2 {
#             background-color:  #e3f1fd;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row0_col3 {
#             background-color:  #e1f0fc;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row0_col4 {
#             background-color:  #e6f3fe;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row1_col0 {
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row1_col1 {
#             background-color:  #045599;
#             color:  #f1f1f1;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row1_col2 {
#             background-color:  #045599;
#             color:  #f1f1f1;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row1_col3 {
#             background-color:  #045599;
#             color:  #f1f1f1;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row1_col4 {
#             background-color:  #045599;
#             color:  #f1f1f1;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row2_col0 {
#             background-color:  #c1d9ee;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row2_col1 {
#             background-color:  #0e5c9d;
#             color:  #f1f1f1;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row2_col2 {
#             background-color:  #1b65a3;
#             color:  #f1f1f1;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row2_col3 {
#             background-color:  #266da8;
#             color:  #f1f1f1;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row2_col4 {
#             background-color:  #0e5c9d;
#             color:  #f1f1f1;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row3_col0 {
#             background-color:  #cce1f3;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row3_col1 {
#             background-color:  #a2c4e0;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row3_col2 {
#             background-color:  #79a7cd;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row3_col3 {
#             background-color:  #76a4cc;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row3_col4 {
#             background-color:  #e4f2fe;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row4_col0 {
#             background-color:  #d2e5f5;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row4_col1 {
#             background-color:  #b4d0e8;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row4_col2 {
#             background-color:  #97bcdb;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row4_col3 {
#             background-color:  #88b2d4;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row4_col4 {
#             background-color:  #e5f3fe;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row5_col0 {
#             background-color:  #d8e9f8;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row5_col1 {
#             background-color:  #d0e4f4;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row5_col2 {
#             background-color:  #a5c6e1;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row5_col3 {
#             background-color:  #98bddb;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row5_col4 {
#             background-color:  #e6f3fe;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row6_col0 {
#             background-color:  #d9eaf8;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row6_col1 {
#             background-color:  #e1f0fc;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row6_col2 {
#             background-color:  #d0e4f4;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row6_col3 {
#             background-color:  #9dc0de;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row6_col4 {
#             background-color:  #e6f3fe;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row7_col0 {
#             background-color:  #dbebf9;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row7_col1 {
#             background-color:  #b9d4ea;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row7_col2 {
#             background-color:  #8eb6d7;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row7_col3 {
#             background-color:  #95bbda;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row7_col4 {
#             background-color:  #e6f3fe;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row8_col0 {
#             background-color:  #dcecfa;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row8_col1 {
#             background-color:  #cce1f2;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row8_col2 {
#             background-color:  #accae4;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row8_col3 {
#             background-color:  #a3c4e0;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row8_col4 {
#             background-color:  #e6f3fe;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row9_col0 {
#             background-color:  #dcecfa;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row9_col1 {
#             background-color:  #e3f1fd;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row9_col2 {
#             background-color:  #e6f3fe;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row9_col3 {
#             background-color:  #e6f3fe;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row9_col4 {
#             background-color:  #e6f3fe;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row10_col0 {
#             background-color:  #ddedfa;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row10_col1 {
#             background-color:  #b3cfe7;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row10_col2 {
#             background-color:  #dcecfa;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row10_col3 {
#             background-color:  #bcd6ec;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row10_col4 {
#             background-color:  #d4e7f6;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row11_col0 {
#             background-color:  #ddedfa;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row11_col1 {
#             background-color:  #bbd5eb;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row11_col2 {
#             background-color:  #a9c8e3;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row11_col3 {
#             background-color:  #b7d2e9;
#             color:  #000000;
#         }    #T_78e0669c_f4b9_11e9_aa15_acde48001122row11_col4 {
#             background-color:  #e6f3fe;
#             color:  #0

# %% [markdown]
# ### 1.2.2. Undersøk forskjeller med frekvenser fra bokhylla

# %% [markdown]
# Tre hundre bøker tar en tid å laste ned og telle opp lokalt så vi teller på server med passende kommando:

# %%
bøker_agg = nb.aggregate_urns(nb.pure_urn(bøker))

# %% [markdown]
# Så konverteres listen over ord og tall til en dataramme

# %%
bøker_df = nb.frame_sort(nb.frame(bøker_agg, 'count'))

# %% [markdown]
# For referanse henter vi ut de 50000 mest frekvente ordene i bokhylla.

# %%
totals = nb.frame(nb.totals(50000), 'tot')

# %% [markdown]
# Sånn ser frekvensene ut for bøkene

# %%
bøker_df.head(10)
# Out:
#       count
# .    140432
# ,    126169
# og    78281
# i     61255
# som   49460
# det   46452
# er    39529
# å     37252
# av    35414
# at    34867

# %% [markdown]
# .. og sånn for bokhylla

# %%
totals.head(10)
# Out:
#             tot
# .    1265723110
# ,    1105303412
# og    543432056
# i     460246057
# det   273411583
# som   265144740
# til   254500136
# er    248764786
# av    235180661
# en    231631623

# %% [markdown]
# Vi finner forskjellen ved å dividere den ene på den andre:

# %%
forskjell = bøker_df['count']/totals['tot']

# %% [markdown]
# Tallene må sorteres, de høyeste tolkes til å være de mest relevante

# %%
bøker_typiske_ord = nb.frame_sort(nb.frame(forskjell, 'ratio'))
bøker_typiske_ord.head(50)
# Out:
#                        ratio
# lesbiske            0.190660
# homofile            0.147121
# homofil             0.112726
# homoseksuelle       0.079942
# sexual              0.020890
# parforhold          0.015570
# seksualitet         0.014638
# seksualiteten       0.013625
# homo                0.013181
# aids                0.011107
# seksuell            0.010779
# tiltrekning         0.009802
# Forbundet           0.008761
# legning             0.008397
# Vita                0.008294
# NOVA                0.008166
# Butler              0.008134
# Lilly               0.007715
# Beauvoir            0.007497
# seksuelle           0.007350
# hiv                 0.007119
# desire              0.006459
# sex                 0.006355
# innvandrerbakgrunn  0.006256
# Moi                 0.006243
# Gender              0.006174
# begjæret            0.005773
# seksuelt            0.005646
# HIV                 0.005445
# identiteter         0.005400
# intervjuede         0.004967
# KrF                 0.004950
# Foucault            0.004938
# feminine            0.004936
# trakassering        0.004726
# Homo                0.004712
# partnerskap         0.004648
# Identity            0.004587
# kjønn               0.004554
# debut               0.004537
# Forbundets          0.004507
# psykiatrien         0.004442
# AIDS                0.004415
# Sex                 0.004238
# Holdninger          0.004126
# samliv              0.004093
# informants          0.004090
# young               0.004085
# adoptere            0.003994
# diskriminering      0.003986

# %% [markdown]
# #### 1.2.2.1. Visualiser som ordsky

# %%
nb.cloud(bøker_typiske_ord.head(50))

# %%
# velg hvor mange ord som skal være med i ordskyen
nb.cloud(bøker_typiske_ord.head(100))

# %% [markdown]
# Tilbake til [DHLAB ved Nasjonalbiblioteket](https://nbviewer.jupyter.org/github/DH-LAB-NB/DHLAB/blob/master/DHLAB_ved_Nasjonalbiblioteket.ipynb)
